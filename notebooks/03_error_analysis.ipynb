# %% [markdown]
# # Error Analysis
#
# Use this notebook after training to inspect false negatives, false positives, and subgroup behavior. This MVP does not make clinical claims from those analyses.
