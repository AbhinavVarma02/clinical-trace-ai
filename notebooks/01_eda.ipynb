# %% [markdown]
# # Clinical-Trace AI EDA
#
# This notebook is a lightweight starter for inspecting the UCI Diabetes dataset. Run `python src/train.py` first if you need the dataset downloaded into `data/raw/`.

# %%
from src.preprocessing import load_raw_data

df = load_raw_data(ensure_download=True)
df.shape, df.dtypes.head()

# %%
df.isna().mean().sort_values(ascending=False).head(15)

# %%
(df["readmitted"].eq("<30")).mean(), df["readmitted"].value_counts(normalize=True)
